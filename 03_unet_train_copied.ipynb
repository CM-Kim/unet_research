# %%
import os
import numpy as np
import cv2
from skimage.transform import resize
import matplotlib.pyplot as plt
from skimage.transform import resize

# %% [markdown]
# # Load image, mask, label

# %%
##Load images, labels, masks
NPY_PATH = r"dataset\numpy"

labels = np.load(os.path.join(NPY_PATH,'labels.npy'))
t1w_images = (np.load(os.path.join(NPY_PATH,'T1W_images.npy')) / 255.0).astype(np.float32)
t2f_images = (np.load(os.path.join(NPY_PATH,'T2F_images.npy')) / 255.0).astype(np.float32)
t2w_images = (np.load(os.path.join(NPY_PATH,'T2W_images.npy')) / 255.0).astype(np.float32)
masks = (np.load(os.path.join(NPY_PATH,'Mask_images.npy')) / 255.0).astype(np.float32)

# %% [markdown]
# # Resize data
#
# 원본 데이터 width : 260 , height : 320
# 결과 데이터 width : 256 , height : 256

# %%
# 모델의 입력 형태에 맞추기 위해 차원을 확장합니다.
# example. (,260,320) -> (,260,320,1)
t1w_images = np.expand_dims(t1w_images,axis=-1)
t2f_images = np.expand_dims(t2f_images,axis=-1)
t2w_images = np.expand_dims(t2w_images,axis=-1)
masks = np.expand_dims(masks,axis=-1)

# %%
from util import downsample

img_size_ori = (260,320)
img_size_target = (256,256)

t1w_images = np.array([ downsample(image,img_size_ori,img_size_target) for image in t1w_images ])
t2f_images = np.array([ downsample(image,img_size_ori,img_size_target) for image in t2f_images ])
t2w_images = np.array([ downsample(image,img_size_ori,img_size_target) for image in t2w_images ])
masks = (np.array([ downsample(mask,img_size_ori,img_size_target) for mask in masks ])>0)*1.0

# %%
from sklearn.model_selection import train_test_split
import gc

image_datasets = np.concatenate((t1w_images,t2f_images,t2w_images),axis=0)
mask_datasets = np.concatenate((masks,masks,masks),axis =0)
labels_datasets = np.concatenate((labels,labels,labels),axis =0)

# %% [markdown]
# ### Train Image and its mask which is to be predicted

# %%
from sklearn.model_selection import train_test_split
import gc
X,X_v,Y,Y_v = train_test_split( image_datasets,mask_datasets,test_size=0.2,stratify=labels_datasets,random_state=444, shuffle=True)

del image_datasets
del mask_datasets
del labels_datasets

gc.collect()

X.shape,X_v.shape
# Out:
# ((5654, 256, 256, 1), (1414, 256, 256, 1))

# %%
from model import baseModel, unet_v1, unet_v2, unet_v3
from keras import optimizers
from util import bce_dice_loss
from keras.metrics import MeanIoU
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, History
from keras.models import load_model
import json
import numpy as np

model_list = [baseModel,unet_v1,unet_v2,unet_v3]
model_name = ['base_256','v1','v2','v3']

for name, model_arch in zip(model_name,model_list):
    unet = model_arch(input_shape=(256,256,1))

    unet.compile(optimizer=optimizers.Adam(lr=1e-3), 
                loss=bce_dice_loss, metrics=['accuracy',MeanIoU(num_classes=2,name="mean_iou")])

    model_name = name
    checkpoint_name = f'model_{model_name}_best_checkpoint.h5'
    history_path = f'model_{model_name}_history.json'

    model_checkpoint  = ModelCheckpoint(checkpoint_name, save_best_only=True, 
                                        monitor='val_loss', mode='min', verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min' , baseline=None)
    reduceLR = ReduceLROnPlateau(patience=4, verbose=2, monitor='val_loss',min_lr=1e-4, mode='min')

    callback_list = [early_stopping, reduceLR, model_checkpoint]

    hist = unet.fit(
                        X,
                        Y,
                        batch_size=16,
                        epochs=100,
                        validation_data=(X_v,Y_v),
                        verbose=1,
                        callbacks= callback_list
            )

    history_dict = hist.history

    class NumpyEncoder(json.JSONEncoder):
        def default(self,obj):
            if isinstance(obj, np.integer):
                return int(obj)
            elif isinstance(obj, np.floating):
                return float(obj)
            elif isinstance(obj,np.ndarray):
                return obj.tolist()
            else:
                return super(NumpyEncoder, self).default(obj)

    with open(history_path,'w') as json_file:
        json.dump(history_dict, json_file, cls=NumpyEncoder)
# Out:
# - val_accuracy: 0.9990 - val_mean_iou: 0.5384
#
# Epoch 00032: val_loss improved from 0.56291 to 0.55627, saving model to model_v1_best_checkpoint.h5
# Epoch 33/100
# 354/354 [==============================] - 242s 683ms/step - loss: 0.4872 - accuracy: 0.9992 - mean_iou: 0.5457 - val_loss: 0.5473 - val_accuracy: 0.9990 - val_mean_iou: 0.5211
#
# Epoch 00033: val_loss improved from 0.55627 to 0.54732, saving model to model_v1_best_checkpoint.h5
# Epoch 34/100
# 354/354 [==============================] - 242s 683ms/step - loss: 0.4708 - accuracy: 0.9991 - mean_iou: 0.5284 - val_loss: 0.5515 - val_accuracy: 0.9990 - val_mean_iou: 0.5144
#
# Epoch 00034: val_loss did not improve from 0.54732
# Epoch 35/100
# 354/354 [==============================] - 242s 683ms/step - loss: 0.4748 - accuracy: 0.9991 - mean_iou: 0.5245 - val_loss: 0.5452 - val_accuracy: 0.9990 - val_mean_iou: 0.5154
#
# Epoch 00035: val_loss improved from 0.54732 to 0.54524, saving model to model_v1_best_checkpoint.h5
# Epoch 36/100
# 354/354 [==============================] - 242s 683ms/step - loss: 0.4722 - accuracy: 0.9991 - mean_iou: 0.5229 - val_loss: 0.5423 - val_accuracy: 0.9990 - val_mean_iou: 0.5166
#
# Epoch 00036: val_loss improved from 0.54524 to 0.54230, saving model to model_v1_best_checkpoint.h5
# Epoch 37/100
# 354/354 [==============================] - 242s 683ms/step - loss: 0.4645 - accuracy: 0.9991 - mean_iou: 0.5221 - val_loss: 0.5451 - val_accuracy: 0.9990 - val_mean_iou: 0.5222
#
# Epoch 00037: val_loss did not improve from 0.54230
# Epoch 38/100
# 354/354 [==============================] - 242s 684ms/step - loss: 0.4361 - accuracy: 0.9992 - mean_iou: 0.5268 - val_loss: 0.5484 - val_accuracy: 0.9990 - val_mean_iou: 0.5129
#
# Epoch 00038: val_loss did not improve from 0.54230
# Epoch 39/100
# 354/354 [==============================] - 242s 683ms/step - loss: 0.4635 - accuracy: 0.9991 - mean_iou: 0.5205 - val_loss: 0.5455 - val_accuracy: 0.9990 - val_mean_iou: 0.5159
#
# Epoch 00039: val_loss did not improve from 0.54230
# Epoch 40/100
# 354/354 [==============================] - 242s 683ms/step - loss: 0.4708 - accuracy: 0.9992 - mean_iou: 0.5241 - val_loss: 0.5447 - val_accuracy: 0.9990 - val_mean_iou: 0.5153
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00040: val_loss did not improve from 0.54230
# Epoch 41/100
# 354/354 [==============================] - 242s 684ms/step - loss: 0.4530 - accuracy: 0.9991 - mean_iou: 0.5256 - val_loss: 0.5438 - val_accuracy: 0.9990 - val_mean_iou: 0.5184
#
# Epoch 00041: val_loss did not improve from 0.54230
# Epoch 1/100
# 354/354 [==============================] - 131s 362ms/step - loss: 1.0214 - accuracy: 0.9858 - mean_iou: 0.4994 - val_loss: 1.0194 - val_accuracy: 0.9987 - val_mean_iou: 0.4994
#
# Epoch 00001: val_loss improved from inf to 1.01936, saving model to model_v2_best_checkpoint.h5
# Epoch 2/100
# 354/354 [==============================] - 126s 357ms/step - loss: 0.9808 - accuracy: 0.9955 - mean_iou: 0.4994 - val_loss: 0.9472 - val_accuracy: 0.9942 - val_mean_iou: 0.4994
#
# Epoch 00002: val_loss improved from 1.01936 to 0.94716, saving model to model_v2_best_checkpoint.h5
# Epoch 3/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.9399 - accuracy: 0.9961 - mean_iou: 0.4994 - val_loss: 0.9316 - val_accuracy: 0.9924 - val_mean_iou: 0.4994
#
# Epoch 00003: val_loss improved from 0.94716 to 0.93156, saving model to model_v2_best_checkpoint.h5
# Epoch 4/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.8440 - accuracy: 0.9978 - mean_iou: 0.4995 - val_loss: 0.8466 - val_accuracy: 0.9986 - val_mean_iou: 0.4994
#
# Epoch 00004: val_loss improved from 0.93156 to 0.84657, saving model to model_v2_best_checkpoint.h5
# Epoch 5/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.7882 - accuracy: 0.9983 - mean_iou: 0.5000 - val_loss: 0.7955 - val_accuracy: 0.9975 - val_mean_iou: 0.5006
#
# Epoch 00005: val_loss improved from 0.84657 to 0.79554, saving model to model_v2_best_checkpoint.h5
# Epoch 6/100
# 354/354 [==============================] - 126s 357ms/step - loss: 0.7546 - accuracy: 0.9983 - mean_iou: 0.5008 - val_loss: 0.7447 - val_accuracy: 0.9980 - val_mean_iou: 0.5195
#
# Epoch 00006: val_loss improved from 0.79554 to 0.74467, saving model to model_v2_best_checkpoint.h5
# Epoch 7/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.7173 - accuracy: 0.9985 - mean_iou: 0.5037 - val_loss: 0.7074 - val_accuracy: 0.9984 - val_mean_iou: 0.5066
#
# Epoch 00007: val_loss improved from 0.74467 to 0.70743, saving model to model_v2_best_checkpoint.h5
# Epoch 8/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.7080 - accuracy: 0.9987 - mean_iou: 0.5076 - val_loss: 0.6794 - val_accuracy: 0.9985 - val_mean_iou: 0.4999
#
# Epoch 00008: val_loss improved from 0.70743 to 0.67944, saving model to model_v2_best_checkpoint.h5
# Epoch 9/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.6783 - accuracy: 0.9987 - mean_iou: 0.5037 - val_loss: 0.7728 - val_accuracy: 0.9988 - val_mean_iou: 0.5006
#
# Epoch 00009: val_loss did not improve from 0.67944
# Epoch 10/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.6728 - accuracy: 0.9987 - mean_iou: 0.5028 - val_loss: 0.6683 - val_accuracy: 0.9988 - val_mean_iou: 0.5081
#
# Epoch 00010: val_loss improved from 0.67944 to 0.66826, saving model to model_v2_best_checkpoint.h5
# Epoch 11/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.6595 - accuracy: 0.9988 - mean_iou: 0.5044 - val_loss: 0.6489 - val_accuracy: 0.9987 - val_mean_iou: 0.5019
#
# Epoch 00011: val_loss improved from 0.66826 to 0.64891, saving model to model_v2_best_checkpoint.h5
# Epoch 12/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.6622 - accuracy: 0.9988 - mean_iou: 0.5082 - val_loss: 0.6363 - val_accuracy: 0.9988 - val_mean_iou: 0.5069
#
# Epoch 00012: val_loss improved from 0.64891 to 0.63630, saving model to model_v2_best_checkpoint.h5
# Epoch 13/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.6713 - accuracy: 0.9987 - mean_iou: 0.5064 - val_loss: 0.6318 - val_accuracy: 0.9988 - val_mean_iou: 0.5066
#
# Epoch 00013: val_loss improved from 0.63630 to 0.63179, saving model to model_v2_best_checkpoint.h5
# Epoch 14/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.6045 - accuracy: 0.9988 - mean_iou: 0.5123 - val_loss: 0.6261 - val_accuracy: 0.9988 - val_mean_iou: 0.5149
#
# Epoch 00014: val_loss improved from 0.63179 to 0.62609, saving model to model_v2_best_checkpoint.h5
# Epoch 15/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.6317 - accuracy: 0.9988 - mean_iou: 0.5094 - val_loss: 0.6014 - val_accuracy: 0.9989 - val_mean_iou: 0.5030
#
# Epoch 00015: val_loss improved from 0.62609 to 0.60138, saving model to model_v2_best_checkpoint.h5
# Epoch 16/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.6087 - accuracy: 0.9989 - mean_iou: 0.5122 - val_loss: 0.6067 - val_accuracy: 0.9989 - val_mean_iou: 0.5021
#
# Epoch 00016: val_loss did not improve from 0.60138
# Epoch 17/100
# 354/354 [==============================] - 127s 358ms/step - loss: 81.0510 - accuracy: 0.9977 - mean_iou: 0.5308 - val_loss: 0.8594 - val_accuracy: 0.9987 - val_mean_iou: 0.4995
#
# Epoch 00017: val_loss did not improve from 0.60138
# Epoch 18/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.7993 - accuracy: 0.9985 - mean_iou: 0.5017 - val_loss: 0.7396 - val_accuracy: 0.9987 - val_mean_iou: 0.5004
#
# Epoch 00018: val_loss did not improve from 0.60138
# Epoch 19/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.7369 - accuracy: 0.9986 - mean_iou: 0.5017 - val_loss: 0.7585 - val_accuracy: 0.9988 - val_mean_iou: 0.4997
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00019: val_loss did not improve from 0.60138
# Epoch 20/100
# 354/354 [==============================] - 127s 358ms/step - loss: 0.7201 - accuracy: 0.9987 - mean_iou: 0.5017 - val_loss: 0.6921 - val_accuracy: 0.9987 - val_mean_iou: 0.5018
#
# Epoch 00020: val_loss did not improve from 0.60138
# Epoch 1/100
# 354/354 [==============================] - 53s 145ms/step - loss: 1.0041 - accuracy: 0.9891 - mean_iou: 0.4994 - val_loss: 1.0150 - val_accuracy: 0.9987 - val_mean_iou: 0.4994
#
# Epoch 00001: val_loss improved from inf to 1.01504, saving model to model_v3_best_checkpoint.h5
# Epoch 2/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.8663 - accuracy: 0.9974 - mean_iou: 0.4999 - val_loss: 0.9984 - val_accuracy: 0.9987 - val_mean_iou: 0.4994
#
# Epoch 00002: val_loss improved from 1.01504 to 0.99838, saving model to model_v3_best_checkpoint.h5
# Epoch 3/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.8573 - accuracy: 0.9982 - mean_iou: 0.5011 - val_loss: 0.7360 - val_accuracy: 0.9986 - val_mean_iou: 0.4997
#
# Epoch 00003: val_loss improved from 0.99838 to 0.73601, saving model to model_v3_best_checkpoint.h5
# Epoch 4/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.7405 - accuracy: 0.9985 - mean_iou: 0.5022 - val_loss: 0.7287 - val_accuracy: 0.9986 - val_mean_iou: 0.5003
#
# Epoch 00004: val_loss improved from 0.73601 to 0.72865, saving model to model_v3_best_checkpoint.h5
# Epoch 5/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.7366 - accuracy: 0.9985 - mean_iou: 0.5035 - val_loss: 0.6883 - val_accuracy: 0.9984 - val_mean_iou: 0.5174
#
# Epoch 00005: val_loss improved from 0.72865 to 0.68833, saving model to model_v3_best_checkpoint.h5
# Epoch 6/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.6748 - accuracy: 0.9987 - mean_iou: 0.5086 - val_loss: 0.6968 - val_accuracy: 0.9987 - val_mean_iou: 0.5082
#
# Epoch 00006: val_loss did not improve from 0.68833
# Epoch 7/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.6878 - accuracy: 0.9987 - mean_iou: 0.5063 - val_loss: 0.7405 - val_accuracy: 0.9988 - val_mean_iou: 0.4995
#
# Epoch 00007: val_loss did not improve from 0.68833
# Epoch 8/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.6741 - accuracy: 0.9987 - mean_iou: 0.5080 - val_loss: 0.7309 - val_accuracy: 0.9985 - val_mean_iou: 0.5000
#
# Epoch 00008: val_loss did not improve from 0.68833
# Epoch 9/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.6580 - accuracy: 0.9986 - mean_iou: 0.5086 - val_loss: 0.7632 - val_accuracy: 0.9988 - val_mean_iou: 0.4997
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00009: val_loss did not improve from 0.68833
# Epoch 10/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.6414 - accuracy: 0.9988 - mean_iou: 0.5120 - val_loss: 0.6140 - val_accuracy: 0.9987 - val_mean_iou: 0.5264
#
# Epoch 00010: val_loss improved from 0.68833 to 0.61398, saving model to model_v3_best_checkpoint.h5
# Epoch 11/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.6178 - accuracy: 0.9988 - mean_iou: 0.5173 - val_loss: 0.5997 - val_accuracy: 0.9988 - val_mean_iou: 0.5118
#
# Epoch 00011: val_loss improved from 0.61398 to 0.59966, saving model to model_v3_best_checkpoint.h5
# Epoch 12/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.5915 - accuracy: 0.9989 - mean_iou: 0.5141 - val_loss: 0.5943 - val_accuracy: 0.9989 - val_mean_iou: 0.5088
#
# Epoch 00012: val_loss improved from 0.59966 to 0.59433, saving model to model_v3_best_checkpoint.h5
# Epoch 13/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.5701 - accuracy: 0.9989 - mean_iou: 0.5135 - val_loss: 0.5820 - val_accuracy: 0.9988 - val_mean_iou: 0.5147
#
# Epoch 00013: val_loss improved from 0.59433 to 0.58199, saving model to model_v3_best_checkpoint.h5
# Epoch 14/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.5717 - accuracy: 0.9989 - mean_iou: 0.5128 - val_loss: 0.5824 - val_accuracy: 0.9989 - val_mean_iou: 0.5073
#
# Epoch 00014: val_loss did not improve from 0.58199
# Epoch 15/100
# 354/354 [==============================] - 50s 141ms/step - loss: 0.5707 - accuracy: 0.9989 - mean_iou: 0.5112 - val_loss: 0.5799 - val_accuracy: 0.9989 - val_mean_iou: 0.5042
#
# Epoch 00015: val_loss improved from 0.58199 to 0.57992, saving model to model_v3_best_checkpoint.h5
# Epoch 16/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5825 - accuracy: 0.9989 - mean_iou: 0.5073 - val_loss: 0.5705 - val_accuracy: 0.9989 - val_mean_iou: 0.5041
#
# Epoch 00016: val_loss improved from 0.57992 to 0.57046, saving model to model_v3_best_checkpoint.h5
# Epoch 17/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5718 - accuracy: 0.9990 - mean_iou: 0.5086 - val_loss: 0.5673 - val_accuracy: 0.9989 - val_mean_iou: 0.5082
#
# Epoch 00017: val_loss improved from 0.57046 to 0.56730, saving model to model_v3_best_checkpoint.h5
# Epoch 18/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5432 - accuracy: 0.9990 - mean_iou: 0.5086 - val_loss: 0.5673 - val_accuracy: 0.9989 - val_mean_iou: 0.5044
#
# Epoch 00018: val_loss did not improve from 0.56730
# Epoch 19/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5694 - accuracy: 0.9989 - mean_iou: 0.5078 - val_loss: 0.5673 - val_accuracy: 0.9989 - val_mean_iou: 0.5042
#
# Epoch 00019: val_loss did not improve from 0.56730
# Epoch 20/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5517 - accuracy: 0.9990 - mean_iou: 0.5083 - val_loss: 0.5638 - val_accuracy: 0.9989 - val_mean_iou: 0.5058
#
# Epoch 00020: val_loss improved from 0.56730 to 0.56379, saving model to model_v3_best_checkpoint.h5
# Epoch 21/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5938 - accuracy: 0.9990 - mean_iou: 0.5062 - val_loss: 0.5647 - val_accuracy: 0.9990 - val_mean_iou: 0.5023
#
# Epoch 00021: val_loss did not improve from 0.56379
# Epoch 22/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5352 - accuracy: 0.9990 - mean_iou: 0.5073 - val_loss: 0.5610 - val_accuracy: 0.9989 - val_mean_iou: 0.5069
#
# Epoch 00022: val_loss improved from 0.56379 to 0.56101, saving model to model_v3_best_checkpoint.h5
# Epoch 23/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5643 - accuracy: 0.9989 - mean_iou: 0.5076 - val_loss: 0.5592 - val_accuracy: 0.9989 - val_mean_iou: 0.5042
#
# Epoch 00023: val_loss improved from 0.56101 to 0.55922, saving model to model_v3_best_checkpoint.h5
# Epoch 24/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5410 - accuracy: 0.9990 - mean_iou: 0.5077 - val_loss: 0.5520 - val_accuracy: 0.9989 - val_mean_iou: 0.5053
#
# Epoch 00024: val_loss improved from 0.55922 to 0.55198, saving model to model_v3_best_checkpoint.h5
# Epoch 25/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5655 - accuracy: 0.9990 - mean_iou: 0.5070 - val_loss: 0.5532 - val_accuracy: 0.9989 - val_mean_iou: 0.5065
#
# Epoch 00025: val_loss did not improve from 0.55198
# Epoch 26/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5391 - accuracy: 0.9990 - mean_iou: 0.5075 - val_loss: 0.5594 - val_accuracy: 0.9989 - val_mean_iou: 0.5098
#
# Epoch 00026: val_loss did not improve from 0.55198
# Epoch 27/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5414 - accuracy: 0.9990 - mean_iou: 0.5089 - val_loss: 0.5561 - val_accuracy: 0.9989 - val_mean_iou: 0.5071
#
# Epoch 00027: val_loss did not improve from 0.55198
# Epoch 28/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5530 - accuracy: 0.9990 - mean_iou: 0.5069 - val_loss: 0.5600 - val_accuracy: 0.9989 - val_mean_iou: 0.5054
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00028: val_loss did not improve from 0.55198
# Epoch 29/100
# 354/354 [==============================] - 50s 142ms/step - loss: 0.5256 - accuracy: 0.9990 - mean_iou: 0.5101 - val_loss: 0.5503 - val_accuracy: 0.9989 - val_mean_iou: 0.5044
#
# Epoch 00029: val_loss improved from 0.55198 to 0.55029, saving model to model_v3_best_checkpoint.h5
# Epoch 30/100
# 354/354 [==============================] - 50s 143ms/step - loss: 0.5347 - accuracy: 0.9990 - mean_iou: 0.5092 - val_loss: 0.5483 - val_accuracy: 0.9990 - val_mean_iou: 0.5036
#
# Epoch 00030: val_loss improved from 0.55029 to 0.54827, saving model to model_v3_best_checkpoint.h5
# Epoch 31/100
# 354/354 [==============================] - 50s 143ms/step - loss: 0.5492 - accuracy: 0.9990 - mean_iou: 0.5079 - val_loss: 0.5483 - val_accuracy: 0.9990 - val_mean_iou: 0.5057
#
# Epoch 00031: val_loss did not improve from 0.54827
# Epoch 32/100
# 354/354 [==============================] - 50s 143ms/step - loss: 0.5285 - accuracy: 0.9990 - mean_iou: 0.5123 - val_loss: 0.5494 - val_accuracy: 0.9990 - val_mean_iou: 0.5053
#
# Epoch 00032: val_loss did not improve from 0.54827
# Epoch 33/100
# 354/354 [==============================] - 51s 143ms/step - loss: 0.5289 - accuracy: 0.9990 - mean_iou: 0.5111 - val_loss: 0.5499 - val_accuracy: 0.9990 - val_mean_iou: 0.5087
#
# Epoch 00033: val_loss did not improve from 0.54827
# Epoch 34/100
# 354/354 [==============================] - 51s 143ms/step - loss: 0.5321 - accuracy: 0.9990 - mean_iou: 0.5128 - val_loss: 0.5463 - val_accuracy: 0.9989 - val_mean_iou: 0.5061
#
# Epoch 00034: val_loss improved from 0.54827 to 0.54628, saving model to model_v3_best_checkpoint.h5
# Epoch 35/100
# 354/354 [==============================] - 51s 143ms/step - loss: 0.5485 - accuracy: 0.9990 - mean_iou: 0.5087 - val_loss: 0.5426 - val_accuracy: 0.9990 - val_mean_iou: 0.5041
#
# Epoch 00035: val_loss improved from 0.54628 to 0.54256, saving model to model_v3_best_checkpoint.h5
# Epoch 36/100
# 354/354 [==============================] - 51s 143ms/step - loss: 0.5074 - accuracy: 0.9990 - mean_iou: 0.5073 - val_loss: 0.5440 - val_accuracy: 0.9990 - val_mean_iou: 0.5116
#
# Epoch 00036: val_loss did not improve from 0.54256
# Epoch 37/100
# 354/354 [==============================] - 51s 143ms/step - loss: 0.5185 - accuracy: 0.9990 - mean_iou: 0.5155 - val_loss: 0.5405 - val_accuracy: 0.9990 - val_mean_iou: 0.5072
#
# Epoch 00037: val_loss improved from 0.54256 to 0.54054, saving model to model_v3_best_checkpoint.h5
# Epoch 38/100
# 354/354 [==============================] - 51s 143ms/step - loss: 0.4873 - accuracy: 0.9991 - mean_iou: 0.5129 - val_loss: 0.5381 - val_accuracy: 0.9989 - val_mean_iou: 0.5143
#
# Epoch 00038: val_loss improved from 0.54054 to 0.53814, saving model to model_v3_best_checkpoint.h5
# Epoch 39/100
# 354/354 [==============================] - 51s 143ms/step - loss: 0.5083 - accuracy: 0.9990 - mean_iou: 0.5129 - val_loss: 0.5368 - val_accuracy: 0.9989 - val_mean_iou: 0.5071
#
# Epoch 00039: val_loss improved from 0.53814 to 0.53680, saving model to model_v3_best_checkpoint.h5
# Epoch 40/100
# 354/354 [==============================] - 51s 144ms/step - loss: 0.5125 - accuracy: 0.9991 - mean_iou: 0.5107 - val_loss: 0.5384 - val_accuracy: 0.9990 - val_mean_iou: 0.5066
#
# Epoch 00040: val_loss did not improve from 0.53680
# Epoch 41/100
# 354/354 [==============================] - 51s 144ms/step - loss: 0.5111 - accuracy: 0.9991 - mean_iou: 0.5109 - val_loss: 0.5438 - val_accuracy: 0.9990 - val_mean_iou: 0.5082
#
# Epoch 00041: val_loss did not improve from 0.53680
# Epoch 42/100
# 354/354 [==============================] - 51s 144ms/step - loss: 0.4966 - accuracy: 0.9991 - mean_iou: 0.5131 - val_loss: 0.5470 - val_accuracy: 0.9990 - val_mean_iou: 0.5071
#
# Epoch 00042: val_loss did not improve from 0.53680
# Epoch 43/100
# 354/354 [==============================] - 51s 144ms/step - loss: 0.5125 - accuracy: 0.9991 - mean_iou: 0.5139 - val_loss: 0.5434 - val_accuracy: 0.9990 - val_mean_iou: 0.5110
#
# Epoch 00043: val_loss did not improve from 0.53680
# Epoch 44/100
# 354/354 [==============================] - 51s 144ms/step - loss: 0.4930 - accuracy: 0.9991 - mean_iou: 0.5122 - val_loss: 0.5397 - val_accuracy: 0.9990 - val_mean_iou: 0.5139
#
# Epoch 00044: val_loss did not improve from 0.53680
